# %%
import pandas as pd
import os
import sys
import warnings
warnings.filterwarnings("ignore")
# Append the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../')))

# %%
from scripts.change_point_analysis import Analyzer
analyzer=Analyzer()

# %%
brent_oil_price_data=pd.read_csv("../assets/data/BrentOilPrices.csv")

# %%
analyzer.cusum_plot(brent_oil_price_data)

# %%
analyzer.rpt_change_point_detection(brent_oil_price_data)

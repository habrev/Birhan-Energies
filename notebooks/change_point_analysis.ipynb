# %%
import pandas as pd
import os
import sys
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the folder path inside Google Drive
drive_folder = "/content/drive/My Drive/scripts"

# Append it to sys.path to allow importing modules
sys.path.append(os.path.abspath(drive_folder))

# %%
from scripts.change_point_analysis import Analyzer
analyzer=Analyzer()

# %%
# !pip3 install ruptures pymc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.0 MB/s eta 0:00:00
# ...

# %%
brent_oil_price_data=pd.read_csv("/content/BrentOilPrices.csv")

# %%
analyzer.cusum_plot(brent_oil_price_data)

# %%
analyzer.rpt_change_point_detection(brent_oil_price_data)
# Out:
# Change Point Dates (actual dates): ['06-Aug-90', '16-Jan-91', '29-Dec-97', '09-Aug-99', '29-Dec-03', '27-Jul-04', '16-Jun-05', '18-May-07', '24-Oct-07', '11-Apr-08', '03-Sep-08', '15-Oct-08', '21-May-09', '13-Oct-09', '30-Nov-10', '17-Feb-11', '15-May-12', '08-Sep-14', '02-Dec-14', '04-Aug-15', '10-May-16', '19-Sep-17', '10-Apr-18', '08-Nov-18', '09-Mar-20', 'May 21, 2020', 'Jan 06, 2021', 'Jun 01, 2021', 'Feb 04, 2022', 'Aug 04, 2022']

# %%
import os
import warnings
import sys
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define the folder path inside Google Drive
drive_folder = "/content/drive/My Drive/scripts"

# Append it to sys.path to allow importing modules
sys.path.append(os.path.abspath(drive_folder))

# %%
from LSTM import LSTM_Modelling
lstm=LSTM_Modelling()

# %%
import pandas as pd
brent_oil_price=pd.read_csv("/content/BrentOilPrices.csv")
brent_oil_price.head()
# Out:
#         Date  Price
# 0  20-May-87  18.63
# 1  21-May-87  18.45
# 2  22-May-87  18.55
# 3  25-May-87  18.60
# 4  26-May-87  18.63

# %%
test_data,y_test,y_pred=lstm.train_lstm(brent_oil_price,'lstm')
# Out:
# Epoch 1/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 19s 64ms/step - loss: 0.0188
# Epoch 2/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - loss: 0.0015
# Epoch 3/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 20s 66ms/step - loss: 0.0014
# Epoch 4/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - loss: 0.0012
# Epoch 5/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 20s 65ms/step - loss: 0.0012
# Epoch 6/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - loss: 0.0010
# Epoch 7/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 20s 65ms/step - loss: 0.0010
# Epoch 8/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - loss: 8.9221e-04
# Epoch 9/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - loss: 8.1076e-04
# Epoch 10/10
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 15s 65ms/step - loss: 7.8762e-04
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Model saved as models/lstm-25-02-2025-19-36-07-00.pkl

# %%
lstm.evaluate_lstm_model(y_test,y_pred)
# Out:
# Mean Absolute Error (MAE): 2.1183707950254806
# Mean Squared Error (MSE): 8.713136606953649
# Root Mean Squared Error (RMSE): 2.951802264202948
# R Square Score (r2_score): 0.9793762997347849
# Mean Absolute Percentage Error (MAPE): 0.03640406381519834 %

# %%
lstm.plot_result(y_test,y_pred)
